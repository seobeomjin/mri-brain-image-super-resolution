# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd 
import os
import glob

idx_list = []
files = glob.glob("/content/gdrive/My Drive/Colab Notebooks/MRI BRAIN image SR/mDCSRN_WGANGP_v2/HCP_1200_NPY_LR/*.npy")
for filepath in files:
  filename_ = filepath.split('/')[-1].split('.')[0]
  filename = filename_.split('_')[0]
  filename = int(filename)
  print(filename)
  idx_list.append(filename)

result = pd.DataFrame(idx_list)
result.to_csv('/content/gdrive/My Drive/Colab Notebooks/MRI BRAIN image SR/mDCSRN_WGANGP_v2/data_prep/HCP_1200_sub.csv',header=False, index= False)
# Out:
# 100408
# 101006
# 100206
# 101309
# 101107
# 100610
# 101410
# 100307
# 101915
# 102008
# 103010
# 102109
# 102513
# 103111
# 102614
# 102816
# 103414
# 103212
# 102715
# 102311
# 105923
# 105620
# 103818
# 105014
# 104416
# 103515
# 104820
# 104012
# 105216
# 105115
# 106016
# 108020
# 107422
# 106319
# 107321
# 107018
# 107220
# 107725
# 106824
# 106521
# 108323
# 108828
# 108525
# 108222
# 109123
# 110007
# 109830
# 109325
# 111514
# 112314
# 111413
# 112112
# 113316
# 111716
# 112819
# 112516
# 113215
# 112920
# 114318
# 114116
# 114419
# 113922
# 114823
# 114621
# 113821
# 113417
# 113619
# 114217
# 110613
# 114924
# 111211
# 111009
# 110411
# 111312
# 116524
# 115825
# 116423
# 115320
# 116221
# 116120
# 115219
# 116726
# 115017
# 115724
# 117930
# 118730
# 117021
# 117122
# 118124
# 118528
# 118225
# 118023
# 117324
# 117728
# 118932
# 119025
# 119732
# 118831
# 119833
# 119126
# 120515
# 121618
# 108121
# 121719
# 120212
# 121416
# 120111
# 120010
# 120717
# 121315
# 120414
# ...
